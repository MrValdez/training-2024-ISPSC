# %%
import pandas as pd

df = pd.read_csv("activities.csv", index_col=0)
print(df)
# Out:
#               activity  participants  required
# Monday       Kasiyahan          1000     False
# Wednesday   Xmas party           500     False
# Friday     Intramurals          1500      True

# %%
print(df.head())
print(df.tail())
# Out:
#               activity  participants  required
# Monday       Kasiyahan          1000     False
# Wednesday   Xmas party           500     False
# Friday     Intramurals          1500      True
#               activity  participants  required
# Monday       Kasiyahan          1000     False
# Wednesday   Xmas party           500     False
# Friday     Intramurals          1500      True

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind="scatter", x="activity", y="participants")
df.plot(kind="bar", x="activity", y="participants")
# Out:
# <Axes: xlabel='activity'>
